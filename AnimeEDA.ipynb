# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#importing libraies

# %%
df = pd.read_csv("animeEda.csv")
#Reading file
df
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 3                                       Sci-Fi, Thriller     TV       24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# ...                                                  ...    ...      ...
# 12289                                             Hentai    OVA        1
# 12290                                             Hentai    OVA        1
# 12291                                             Hentai    OVA        4
# 12292                                             Hentai    OVA        1
# 12293                                             Hentai  Movie        1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12294 rows x 7 columns]

# %%
df.head()
#load data
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
df.tail()
# Out:
#        anime_id                                               name   genre  \
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami  Hentai
# 12290      5543                                        Under World  Hentai
# 12291      5621                     Violence Gekiga David no Hoshi  Hentai
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...  Hentai
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!  Hentai
#
#         type episodes  rating  members
# 12289    OVA        1    4.15      211
# 12290    OVA        1    4.28      183
# 12291    OVA        4    4.88      219
# 12292    OVA        1    4.98      175
# 12293  Movie        1    5.46      142

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %%
df.columns
# Out:
# Index(['anime_id', 'name', 'genre', 'type', 'episodes', 'rating', 'members'], dtype='object')

# %%
df.shape
# Out:
# (12294, 7)

# %%
df.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
#changing ep datatype to int
df["episodes"] = pd.to_numeric(df["episodes"], errors="coerce")

df["episodes"] = df["episodes"].fillna(df["episodes"].mean())

df["episodes"] = df["episodes"].astype(int)
df
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type  episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie         1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV        64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV        51
# 3                                       Sci-Fi, Thriller     TV        24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV        51
# ...                                                  ...    ...       ...
# 12289                                             Hentai    OVA         1
# 12290                                             Hentai    OVA         1
# 12291                                             Hentai    OVA         4
# 12292                                             Hentai    OVA         1
# 12293                                             Hentai  Movie         1
#
#        rating  members
# 0        9.37   200630
# 1        9.26   793665
# 2        9.25   114262
# 3        9.17   673572
# 4        9.16   151266
# ...       ...      ...
# 12289    4.15      211
# 12290    4.28      183
# 12291    4.88      219
# 12292    4.98      175
# 12293    5.46      142
#
# [12294 rows x 7 columns]

# %%
#sorting rating
df = df.sort_values(by="rating", ascending=False)
df
# Out:
#        anime_id                                               name  \
# 10464     33662            Taka no Tsume 8: Yoshida-kun no X-Files
# 10400     30120                        Spoon-hime no Swing Kitchen
# 9595      23005                                   Mogura no Motoro
# 0         32281                                     Kimi no Na wa.
# 9078      33607                                       Kahei no Umi
# ...         ...                                                ...
# 12274     34492  Nuki Doki! Tenshi to Akuma no Sakusei Battle -...
# 12279     34491                       Sagurare Otome The Animation
# 12280     34312                                       Saimin Class
# 12282     34388                    Shikkoku no Shaga The Animation
# 12285     34399                                   Taimanin Asagi 3
#
#                                       genre   type  episodes  rating  members
# 10464                        Comedy, Parody  Movie         1   10.00       13
# 10400                       Adventure, Kids     TV        12    9.60       47
# 9595                          Slice of Life  Movie         1    9.50       62
# 0      Drama, Romance, School, Supernatural  Movie         1    9.37   200630
# 9078                             Historical  Movie         1    9.33       44
# ...                                     ...    ...       ...     ...      ...
# 12274                                Hentai    OVA        12     NaN      392
# 12279                                Hentai    OVA         1     NaN       79
# 12280                                Hentai    OVA        12     NaN      240
# 12282                                Hentai    OVA        12     NaN      195
# 12285          Demons, Hentai, Supernatural    OVA        12     NaN      485
#
# [12294 rows x 7 columns]

# %%
#creating rank
df["rating"] = pd.to_numeric(df["rating"], errors="coerce")

# remove rows where rating is missing

# sort by rating
df = df.sort_values(by="rating", ascending=False)
df
# Out:
#        anime_id                                               name  \
# 10464     33662            Taka no Tsume 8: Yoshida-kun no X-Files
# 10400     30120                        Spoon-hime no Swing Kitchen
# 9595      23005                                   Mogura no Motoro
# 0         32281                                     Kimi no Na wa.
# 9078      33607                                       Kahei no Umi
# ...         ...                                                ...
# 12274     34492  Nuki Doki! Tenshi to Akuma no Sakusei Battle -...
# 12279     34491                       Sagurare Otome The Animation
# 12280     34312                                       Saimin Class
# 12282     34388                    Shikkoku no Shaga The Animation
# 12285     34399                                   Taimanin Asagi 3
#
#                                       genre   type  episodes  rating  members
# 10464                        Comedy, Parody  Movie         1   10.00       13
# 10400                       Adventure, Kids     TV        12    9.60       47
# 9595                          Slice of Life  Movie         1    9.50       62
# 0      Drama, Romance, School, Supernatural  Movie         1    9.37   200630
# 9078                             Historical  Movie         1    9.33       44
# ...                                     ...    ...       ...     ...      ...
# 12274                                Hentai    OVA        12     NaN      392
# 12279                                Hentai    OVA         1     NaN       79
# 12280                                Hentai    OVA        12     NaN      240
# 12282                                Hentai    OVA        12     NaN      195
# 12285          Demons, Hentai, Supernatural    OVA        12     NaN      485
#
# [12294 rows x 7 columns]

# %%
#sorting
df = df.sort_values(by="rating", ascending=False)
#rank
df["rank"] = df["rating"].rank(method="dense", ascending=False)
df
# Out:
#        anime_id                                               name  \
# 10464     33662            Taka no Tsume 8: Yoshida-kun no X-Files
# 10400     30120                        Spoon-hime no Swing Kitchen
# 9595      23005                                   Mogura no Motoro
# 0         32281                                     Kimi no Na wa.
# 9078      33607                                       Kahei no Umi
# ...         ...                                                ...
# 12274     34492  Nuki Doki! Tenshi to Akuma no Sakusei Battle -...
# 12279     34491                       Sagurare Otome The Animation
# 12280     34312                                       Saimin Class
# 12282     34388                    Shikkoku no Shaga The Animation
# 12285     34399                                   Taimanin Asagi 3
#
#                                       genre   type  episodes  rating  members  \
# 10464                        Comedy, Parody  Movie         1   10.00       13
# 10400                       Adventure, Kids     TV        12    9.60       47
# 9595                          Slice of Life  Movie         1    9.50       62
# 0      Drama, Romance, School, Supernatural  Movie         1    9.37   200630
# 9078                             Historical  Movie         1    9.33       44
# ...                                     ...    ...       ...     ...      ...
# 12274                                Hentai    OVA        12     NaN      392
# 12279                                Hentai    OVA         1     NaN       79
# 12280                                Hentai    OVA        12     NaN      240
# 12282                                Hentai    OVA        12     NaN      195
# 12285          Demons, Hentai, Supernatural    OVA        12     NaN      485
#
#        rank
# 10464   1.0
# 10400   2.0
# 9595    3.0
# 0       4.0
# 9078    5.0
# ...     ...
# 12274   NaN
# 12279   NaN
# 12280   NaN
# 12282   NaN
# 12285   NaN
#
# [12294 rows x 8 columns]

# %%
df=df.dropna()
df.isnull().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# rank        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#        anime_id                                     name  \
# 10464     33662  Taka no Tsume 8: Yoshida-kun no X-Files
# 10400     30120              Spoon-hime no Swing Kitchen
# 9595      23005                         Mogura no Motoro
# 0         32281                           Kimi no Na wa.
# 9078      33607                             Kahei no Umi
# ...         ...                                      ...
# 8056        413                          Hametsu no Mars
# 8057      13405                       Utsu Musume Sayuri
# 8058       3287             Tenkuu Danzai Skelter+Heaven
# 12258     20007            Hi Gekiga Ukiyoe Senya Ichiya
# 9991      34476       Platonic Chain: Ansatsu Jikkouchuu
#
#                                       genre     type  episodes  rating  \
# 10464                        Comedy, Parody    Movie         1   10.00
# 10400                       Adventure, Kids       TV        12    9.60
# 9595                          Slice of Life    Movie         1    9.50
# 0      Drama, Romance, School, Supernatural    Movie         1    9.37
# 9078                             Historical    Movie         1    9.33
# ...                                     ...      ...       ...     ...
# 8056                         Horror, Sci-Fi      OVA         1    2.37
# 8057                       Comedy, Dementia      OVA         1    2.14
# 8058                          Mecha, Sci-Fi      OVA         1    2.00
# 12258                        Action, Hentai    Movie         1    1.92
# 9991                  Sci-Fi, Slice of Life  Special         1    1.67
#
#        members   rank
# 10464       13    1.0
# 10400       47    2.0
# 9595        62    3.0
# 0       200630    4.0
# 9078        44    5.0
# ...        ...    ...
# 8056     27557  594.0
# 8057      4047  595.0
# 8058      7680  596.0
# 12258      129  597.0
# 9991        51  598.0
#
# [12017 rows x 8 columns]

# %%
# split genres for top rated animes
genre_df = df.assign(genre=df["genre"].str.split(","))
genre_df = genre_df.explode("genre")
genre_df["genre"] = genre_df["genre"].str.strip()
top_genre = genre_df.sort_values("rating", ascending=False).groupby("genre").head(1)
top_genre[["genre","name","rating"]]
# Out:
#                genre                                               name  \
# 10464         Comedy            Taka no Tsume 8: Yoshida-kun no X-Files
# 10464         Parody            Taka no Tsume 8: Yoshida-kun no X-Files
# 10400      Adventure                        Spoon-hime no Swing Kitchen
# 10400           Kids                        Spoon-hime no Swing Kitchen
# 9595   Slice of Life                                   Mogura no Motoro
# 0              Drama                                     Kimi no Na wa.
# 0            Romance                                     Kimi no Na wa.
# 0             School                                     Kimi no Na wa.
# 0       Supernatural                                     Kimi no Na wa.
# 9078      Historical                                       Kahei no Umi
# 1            Fantasy                   Fullmetal Alchemist: Brotherhood
# 1           Military                   Fullmetal Alchemist: Brotherhood
# 1              Magic                   Fullmetal Alchemist: Brotherhood
# 1            Shounen                   Fullmetal Alchemist: Brotherhood
# 1             Action                   Fullmetal Alchemist: Brotherhood
# 2            Samurai                                           Gintama°
# 2             Sci-Fi                                           Gintama°
# 3           Thriller                                        Steins;Gate
# 5             Sports  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6        Super Power                             Hunter x Hunter (2011)
# 7              Space                               Ginga Eiyuu Densetsu
# 13             Mecha                 Code Geass: Hangyaku no Lelouch R2
# 16             Music                            Shigatsu wa Kimi no Uso
# 17           Mystery                      Mushishi Zoku Shou 2nd Season
# 17            Seinen                      Mushishi Zoku Shou 2nd Season
# 21      Martial Arts  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...
# 26           Vampire                   Monogatari Series: Second Season
# 31            Shoujo                              Natsume Yuujinchou Go
# 38            Horror                                            Monster
# 38            Police                                            Monster
# 38     Psychological                                            Monster
# 52            Demons                   Kamisama Hajimemashita: Kako-hen
# 61             Ecchi                                 Shokugeki no Souma
# 68             Josei                      Shouwa Genroku Rakugo Shinjuu
# 89        Shounen Ai                                 Doukyuusei (Movie)
# 93              Game                                      Chihayafuru 2
# 130         Dementia     Neon Genesis Evangelion: The End of Evangelion
# 164            Harem                             Ouran Koukou Host Club
# 12251         Hentai  Chou Do M na Hentai Mesu-tachi Otokoton Chouky...
# 203             Cars                                            Redline
# 485        Shoujo Ai                                 Yuru Yuri San☆Hai!
# 11118           Yaoi                                       Fuyu no Semi
# 11138           Yuri  Sono Hanabira ni Kuchizuke wo: Anata to Koibit...
#
#        rating
# 10464   10.00
# 10464   10.00
# 10400    9.60
# 10400    9.60
# 9595     9.50
# 0        9.37
# 0        9.37
# 0        9.37
# 0        9.37
# 9078     9.33
# 1        9.26
# 1        9.26
# 1        9.26
# 1        9.26
# 1        9.26
# 2        9.25
# 2        9.25
# 3        9.17
# 5        9.15
# 6        9.13
# 7        9.11
# 13       8.98
# 16       8.92
# 17       8.88
# 17       8.88
# 21       8.83
# 26       8.80
# 31       8.76
# 38       8.72
# 38       8.72
# 38       8.72
# 52       8.64
# 61       8.61
# 68       8.59
# 89       8.53
# 93       8.52
# 130      8.45
# 164      8.39
# 12251    8.38
# 203      8.33
# 485      8.04
# 11118    7.74
# 11138    7.40

# %%
# split genre for Most Popular Anime
genre_df = df.assign(genre=df["genre"].str.split(","))


genre_df = genre_df.explode("genre")


genre_df["genre"] = genre_df["genre"].str.strip()

popular_genre = genre_df.sort_values("members", ascending=False).groupby("genre").head(1)

popular_genre[["genre","name","members"]]
# Out:
#                genre                              name  members
# 40            Police                        Death Note  1013917
# 40     Psychological                        Death Note  1013917
# 40      Supernatural                        Death Note  1013917
# 40          Thriller                        Death Note  1013917
# 40           Mystery                        Death Note  1013917
# 86            Action                Shingeki no Kyojin   896229
# 86           Shounen                Shingeki no Kyojin   896229
# 86           Fantasy                Shingeki no Kyojin   896229
# 86             Drama                Shingeki no Kyojin   896229
# 86       Super Power                Shingeki no Kyojin   896229
# 804          Romance                  Sword Art Online   893100
# 804             Game                  Sword Art Online   893100
# 804        Adventure                  Sword Art Online   893100
# 1              Magic  Fullmetal Alchemist: Brotherhood   793665
# 1           Military  Fullmetal Alchemist: Brotherhood   793665
# 159           Comedy                      Angel Beats!   717796
# 159           School                      Angel Beats!   717796
# 19             Mecha   Code Geass: Hangyaku no Lelouch   715151
# 19            Sci-Fi   Code Geass: Hangyaku no Lelouch   715151
# 841     Martial Arts                            Naruto   683297
# 131    Slice of Life                         Toradora!   633817
# 760           Horror                        Elfen Lied   623511
# 760           Seinen                        Elfen Lied   623511
# 118            Ecchi                   No Game No Life   602291
# 643           Demons                    Ao no Exorcist   583823
# 23            Parody                     One Punch Man   552458
# 22             Space                      Cowboy Bebop   486824
# 160          Vampire                    Bakemonogatari   482268
# 211         Dementia           Neon Genesis Evangelion   461946
# 458       Historical                      Kuroshitsuji   424919
# 164           Shoujo            Ouran Koukou Host Club   422271
# 164            Harem            Ouran Koukou Host Club   422271
# 16             Music           Shigatsu wa Kimi no Uso   416397
# 104          Samurai                  Samurai Champloo   390076
# 122           Sports                  Kuroko no Basket   338315
# 1834            Kids                           Pokemon   229157
# 80             Josei                        Usagi Drop   194855
# 1075       Shoujo Ai                         Yuru Yuri   148140
# 437       Shounen Ai                  Junjou Romantica   117910
# 203             Cars                           Redline   109392
# 12217           Yaoi                      Boku no Pico    57355
# 12217         Hentai                      Boku no Pico    57355
# 11566           Yuri            Aki-Sora: Yume no Naka    37519

# %%
# Most Popular Anime in Each Genre
genre_df = df.assign(genre=df["genre"].str.split(","))

genre_df = genre_df.explode("genre")

genre_df["genre"] = genre_df["genre"].str.strip()

popular_unique = genre_df.loc[genre_df.groupby("genre")["members"].idxmax()]

# combine genres for same anime
combined = popular_unique.groupby("name").agg({
    "genre": lambda x: ", ".join(sorted(set(x))),
    "members": "first"
}).reset_index()

# sort by popularity
combined = combined.sort_values("members", ascending=False)

combined
# Out:
#                                 name  \
# 7                         Death Note
# 22                Shingeki no Kyojin
# 23                  Sword Art Online
# 9   Fullmetal Alchemist: Brotherhood
# 1                       Angel Beats!
# 5    Code Geass: Hangyaku no Lelouch
# 13                            Naruto
# 24                         Toradora!
# 8                         Elfen Lied
# 15                   No Game No Life
# 2                     Ao no Exorcist
# 16                     One Punch Man
# 6                       Cowboy Bebop
# 3                     Bakemonogatari
# 14           Neon Genesis Evangelion
# 12                      Kuroshitsuji
# 17            Ouran Koukou Host Club
# 21           Shigatsu wa Kimi no Uso
# 20                  Samurai Champloo
# 11                  Kuroko no Basket
# 18                           Pokemon
# 25                        Usagi Drop
# 26                         Yuru Yuri
# 10                  Junjou Romantica
# 19                           Redline
# 4                       Boku no Pico
# 0             Aki-Sora: Yume no Naka
#
#                                                 genre  members
# 7   Mystery, Police, Psychological, Supernatural, ...  1013917
# 22       Action, Drama, Fantasy, Shounen, Super Power   896229
# 23          Action, Adventure, Fantasy, Game, Romance   893100
# 9   Action, Adventure, Drama, Fantasy, Magic, Mili...   793665
# 1         Action, Comedy, Drama, School, Supernatural   717796
# 5   Action, Mecha, Military, School, Sci-Fi, Super...   715151
# 13  Action, Comedy, Martial Arts, Shounen, Super P...   683297
# 24             Comedy, Romance, School, Slice of Life   633817
# 8   Action, Drama, Horror, Psychological, Romance,...   623511
# 15  Adventure, Comedy, Ecchi, Fantasy, Game, Super...   602291
# 2      Action, Demons, Fantasy, Shounen, Supernatural   583823
# 16  Action, Comedy, Parody, Sci-Fi, Seinen, Super ...   552458
# 6     Action, Adventure, Comedy, Drama, Sci-Fi, Space   486824
# 3             Mystery, Romance, Supernatural, Vampire   482268
# 14  Action, Dementia, Drama, Mecha, Psychological,...   461946
# 12  Action, Comedy, Demons, Fantasy, Historical, S...   424919
# 17             Comedy, Harem, Romance, School, Shoujo   422271
# 21             Drama, Music, Romance, School, Shounen   416397
# 20  Action, Adventure, Comedy, Historical, Samurai...   390076
# 11                    Comedy, School, Shounen, Sports   338315
# 18           Action, Adventure, Comedy, Fantasy, Kids   229157
# 25                               Josei, Slice of Life   194855
# 26           Comedy, School, Shoujo Ai, Slice of Life   148140
# 10                 Comedy, Drama, Romance, Shounen Ai   117910
# 19                       Action, Cars, Sci-Fi, Sports   109392
# 4                                        Hentai, Yaoi    57355
# 0                        Ecchi, Romance, Seinen, Yuri    37519

# %%
#Best anime for kinds
kids_anime = df[df["genre"].str.contains("Kids", case=False, na=False)]
top_kids = kids_anime.sort_values(by="rating", ascending=False).head(10)
top_kids[["name","genre","rating"]]
# Out:
#                                                     name  \
# 10400                        Spoon-hime no Swing Kitchen
# 10786                    Yakusoku: Africa Mizu to Midori
# 9831                                   Okaachan Gomen ne
# 10136                          Santa-san wa Dai Isogashi
# 9539           Mienu Me ni Kanjita Kumotoriyama no Asahi
# 10847                                    Yume no Tsuzuki
# 9208                 Kie Saranu Kizuato: Hi no Umi Osaka
# 9567                                    Minna no Doutoku
# 10793  Yamete! Writer Asobi: Doubutsu Mura no Shoubou...
# 9574     Mirai e no Niji: Boku no Ojisan wa, Hansen-byou
#
#                                           genre  rating
# 10400                           Adventure, Kids    9.60
# 10786                               Drama, Kids    9.25
# 9831                           Historical, Kids    9.00
# 10136                             Fantasy, Kids    9.00
# 9539                                Drama, Kids    9.00
# 10847                               Drama, Kids    8.67
# 9208                           Historical, Kids    8.67
# 9567   Drama, Fantasy, Historical, Kids, School    8.67
# 10793                               Drama, Kids    8.67
# 9574                                Drama, Kids    8.50

# %%
#Best anime for teenager
teen_anime = df[df["genre"].str.contains("Shounen|School|Action", case=False, na=False)]
top_teen = teen_anime.sort_values(by="rating", ascending=False).head(10)
top_teen[["name","genre","rating"]]
# Out:
#                                                  name  \
# 0                                      Kimi no Na wa.
# 1                    Fullmetal Alchemist: Brotherhood
# 2                                            Gintama°
# 4                                       Gintama&#039;
# 5   Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6                              Hunter x Hunter (2011)
# 9                            Gintama&#039;: Enchousen
# 8   Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 11                                     Koe no Katachi
# 12                                            Gintama
#
#                                                 genre  rating
# 0                Drama, Romance, School, Supernatural    9.37
# 1   Action, Adventure, Drama, Fantasy, Magic, Mili...    9.26
# 2   Action, Comedy, Historical, Parody, Samurai, S...    9.25
# 4   Action, Comedy, Historical, Parody, Samurai, S...    9.16
# 5              Comedy, Drama, School, Shounen, Sports    9.15
# 6             Action, Adventure, Shounen, Super Power    9.13
# 9   Action, Comedy, Historical, Parody, Samurai, S...    9.11
# 8   Action, Comedy, Historical, Parody, Samurai, S...    9.10
# 11                             Drama, School, Shounen    9.05
# 12  Action, Comedy, Historical, Parody, Samurai, S...    9.04

# %%
#Best Anime for Adults
adult_anime = df[df["genre"].str.contains("Psychological|Seinen|Thriller", na=False)]
adult_anime.sort_values("rating", ascending=False)[["name","genre","rating"]].head(10)
# Out:
#                                    name  \
# 3                           Steins;Gate
# 17        Mushishi Zoku Shou 2nd Season
# 23                        One Punch Man
# 27                   Mushishi Zoku Shou
# 28                             Mushishi
# 33  Mushishi Zoku Shou: Suzu no Shizuku
# 36                 Fate/Zero 2nd Season
# 38                              Monster
# 40                           Death Note
# 45       Kara no Kyoukai 5: Mujun Rasen
#
#                                                 genre  rating
# 3                                    Sci-Fi, Thriller    9.17
# 17  Adventure, Fantasy, Historical, Mystery, Seine...    8.88
# 23  Action, Comedy, Parody, Sci-Fi, Seinen, Super ...    8.82
# 27  Adventure, Fantasy, Historical, Mystery, Seine...    8.80
# 28  Adventure, Fantasy, Historical, Mystery, Seine...    8.78
# 33  Adventure, Fantasy, Historical, Mystery, Seine...    8.75
# 36            Action, Fantasy, Supernatural, Thriller    8.73
# 38  Drama, Horror, Mystery, Police, Psychological,...    8.72
# 40  Mystery, Police, Psychological, Supernatural, ...    8.71
# 45  Action, Drama, Mystery, Romance, Supernatural,...    8.68

# %%
#Compare between kids/teenaggers/adults
def age_group(genre):
    if "Kids" in str(genre):
        return "Kids"
    elif "Shounen" in str(genre) or "School" in str(genre) or "Action" in str(genre):
        return "Teen"
    elif "Seinen" in str(genre) or "Psychological" in str(genre) or "Thriller" in str(genre):
        return "Adult"
    else:
        return "General"

df["age_group"] = df["genre"].apply(age_group)
top_age = df.sort_values("rating", ascending=False).groupby("age_group").head(5)
top_age[["age_group","name","rating"]]
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_11096\4053032435.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["age_group"] = df["genre"].apply(age_group)
#       age_group                                               name  rating
# 10464   General            Taka no Tsume 8: Yoshida-kun no X-Files   10.00
# 10400      Kids                        Spoon-hime no Swing Kitchen    9.60
# 9595    General                                   Mogura no Motoro    9.50
# 0          Teen                                     Kimi no Na wa.    9.37
# 9078    General                                       Kahei no Umi    9.33
# 1          Teen                   Fullmetal Alchemist: Brotherhood    9.26
# 2          Teen                                           Gintama°    9.25
# 10786      Kids                    Yakusoku: Africa Mizu to Midori    9.25
# 3         Adult                                        Steins;Gate    9.17
# 4          Teen                                      Gintama&#039;    9.16
# 5          Teen  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...    9.15
# 7       General                               Ginga Eiyuu Densetsu    9.11
# 10      General                               Clannad: After Story    9.06
# 10136      Kids                          Santa-san wa Dai Isogashi    9.00
# 9831       Kids                                  Okaachan Gomen ne    9.00
# 9539       Kids          Mienu Me ni Kanjita Kumotoriyama no Asahi    9.00
# 17        Adult                      Mushishi Zoku Shou 2nd Season    8.88
# 27        Adult                                 Mushishi Zoku Shou    8.80
# 28        Adult                                           Mushishi    8.78
# 33        Adult                Mushishi Zoku Shou: Suzu no Shizuku    8.75

# %%
df = df.reset_index(drop=True)
df
# Out:
#        anime_id                                     name  \
# 0         33662  Taka no Tsume 8: Yoshida-kun no X-Files
# 1         30120              Spoon-hime no Swing Kitchen
# 2         23005                         Mogura no Motoro
# 3         32281                           Kimi no Na wa.
# 4         33607                             Kahei no Umi
# ...         ...                                      ...
# 12012       413                          Hametsu no Mars
# 12013     13405                       Utsu Musume Sayuri
# 12014      3287             Tenkuu Danzai Skelter+Heaven
# 12015     20007            Hi Gekiga Ukiyoe Senya Ichiya
# 12016     34476       Platonic Chain: Ansatsu Jikkouchuu
#
#                                       genre     type  episodes  rating  \
# 0                            Comedy, Parody    Movie         1   10.00
# 1                           Adventure, Kids       TV        12    9.60
# 2                             Slice of Life    Movie         1    9.50
# 3      Drama, Romance, School, Supernatural    Movie         1    9.37
# 4                                Historical    Movie         1    9.33
# ...                                     ...      ...       ...     ...
# 12012                        Horror, Sci-Fi      OVA         1    2.37
# 12013                      Comedy, Dementia      OVA         1    2.14
# 12014                         Mecha, Sci-Fi      OVA         1    2.00
# 12015                        Action, Hentai    Movie         1    1.92
# 12016                 Sci-Fi, Slice of Life  Special         1    1.67
#
#        members   rank age_group
# 0           13    1.0   General
# 1           47    2.0      Kids
# 2           62    3.0   General
# 3       200630    4.0      Teen
# 4           44    5.0   General
# ...        ...    ...       ...
# 12012    27557  594.0   General
# 12013     4047  595.0   General
# 12014     7680  596.0   General
# 12015      129  597.0      Teen
# 12016       51  598.0   General
#
# [12017 rows x 9 columns]

# %%
df.to_csv("anime_cleaned.csv", index=False)

# %%
#Creating EDA
sns.countplot(x='type', data=df)
plt.title("Anime Type Distribution")
plt.show()

# %%
sns.histplot(df["rating"], bins=20)
plt.title("Rating Distribution")
plt.show()

# %%
top_rated = df.sort_values("rating", ascending=False).head(10)
sns.barplot(x="rating", y="name", data=top_rated)
plt.title("Top Rated Anime")
plt.show()

# %%
top10_genre = top_genre.sort_values("rating", ascending=False).head(10)

plt.figure(figsize=(8,6))
sns.barplot(x="rating", y="genre", data=top10_genre)

plt.title("Top Rated Anime by Genre")
plt.show()

# %%
popular = df.sort_values("members", ascending=False).head(5)
sns.barplot(x="members", y="name", data=popular)
plt.title("Most Popular Anime")
plt.show()

# %%
top10_popular = popular_genre.sort_values("members", ascending=False).head(10)

plt.figure(figsize=(8,6))
sns.barplot(x="members", y="genre", data=top10_popular)

plt.title("Most Popular Anime by Genre")
plt.show()

# %%
df.groupby("type")["rating"].mean().plot(kind="bar")
plt.title("Average Rating by Type")
plt.show()

# %%
genre = df['genre'].str.split(',', expand=True).stack()

genre.value_counts().head(10).plot(kind="bar")
plt.title("Top Genres")
plt.show()

# %%
# create label with name and genre
combined["label"] = combined["name"] + " (" + combined["genre"] + ")"

# sort by popularity
top10 = combined.sort_values("members", ascending=False).head(10)

plt.figure(figsize=(10,6))

sns.barplot(x="members", y="label", data=top10)

plt.title("Top 10 Most Popular Anime with Genres")
plt.xlabel("Members")
plt.ylabel("Anime + Genre")

plt.show()

# %%
plt.figure(figsize=(8,6))

sns.barplot(x="rating", y="name", data=top_kids)

plt.title("Top 10 Anime for Kids")
plt.xlabel("Rating")
plt.ylabel("Anime Name")

plt.show()

# %%
plt.figure(figsize=(8,6))

sns.barplot(x="rating", y="name", data=top_teen)

plt.title("Top 10 Anime for Teen Audience")
plt.xlabel("Rating")
plt.ylabel("Anime Name")

plt.show()

# %%
top_adult = adult_anime.sort_values("rating", ascending=False).head(10)

sns.barplot(x="rating", y="name", data=top_adult)

plt.title("Top Anime for Adult Audience")
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.barplot(x="rating", y="name", hue="age_group", data=top_age)

plt.title("Top Anime by Age Group")

plt.show()

# %%
long_anime = df.sort_values("episodes", ascending=False).head(10)

sns.barplot(x="episodes", y="name", data=long_anime)
plt.title("Longest Anime")
plt.show()

# %%
df["episodes"] = pd.to_numeric(df["episodes"], errors="coerce")
df["episodes"] = df["episodes"].fillna(df["episodes"].mean())
df.groupby("type")["episodes"].mean().plot(kind="bar")
plt.title("Average Episodes by Type")
plt.show()

# %%
sns.histplot(df["members"], bins=30)
plt.title("Members Distribution")
plt.show()

# %%
df.groupby("type")["members"].sum().plot(kind="bar")
plt.title("Members by Type")
plt.show()

# %%
# 1 Anime Type Distribution
plt.savefig("anime_type_distribution.png")



# 2 Top Rated Anime by Genre
plt.savefig("top_rated_genre.png")


# 3 Top Anime by Age Group
plt.savefig("top_anime_age_group.png")
